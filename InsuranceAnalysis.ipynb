# %% [markdown]
# <a href="https://colab.research.google.com/github/jcastiblanco/-Fundamentos-de-IA-y-Machine-Learning/blob/main/InsuranceAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejercicio de la semana 1**
#
# 1. Desde el folder de google, se hace la conexión al drive
# 2. Importar librería de pandas para analizar dataframes
# 3. Cargar el fichero de kaggle de insurance
# 4. Realizar una primera revisión a todo el dataset cargado en memoria
# 5. Realizar una revisión rápida a las primeras filas **head()**.
# 6. Realizar una revisión de estadística descriptiva con **Describe()**.
# 7. Uso de la funcion **Shape()** para conocer rápidamente el número de filas (muestras) y el número de columnas (variables) de mi conjunto de datos.
# 8. Uso de la funcion **isnull()** para conocer el número de muestras sin datos para cada columna. Se utiliza para seleccionar las columnas que pueden no aportar valor en el entrenamiento del modelo.
# 9. Uso de la funcion **columns()** para conocer el nombre de las columnas.
# 10. Uso de la función **dtypes()** para conocer el tipo de dato de cada variable.

# %% [markdown]
# **Carga de información desde un archivo de texto**

# %%
#importa archivo local
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a4d66e66-0f6f-444a-8b7e-2533c1e4ba19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4d66e66-0f6f-444a-8b7e-2533c1e4ba19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Carga de información directamente desde Kaggle**

# %%
#Impota Archivo desde Kaggle
from google.colab import files
# !pip install -q kaggle

# %%
#cargar kaggle.json personal
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a4d4f1a8-48ab-4370-94ea-bfaab1676b71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4d4f1a8-48ab-4370-94ea-bfaab1676b71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Importa Librerias
import pandas as pd

# %%
#Se carga el API Key en la ruta necearia, luego se descarga el dataset, 
#se descomprime y por último se carga el dataframe en una variable
#para visualizarlo
# !mv kaggle.json /root/.kaggle/kaggle.json
# !kaggle datasets download -d mirichoi0218/insurance
# !unzip insurance.zip
ds_insurance=pd.read_csv("./insurance.csv")
ds_insurance
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory
# ...
# insurance.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  insurance.zip
# replace insurance.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: insurance.csv
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# ...

# %% [markdown]
# **Carga de información desde el drive de google**

# %%
#Carga el archivo en memoria
df=pd.read_csv("/content/drive/MyDrive/maestria2023/modulo1/machineLearningAI/week1/insurance.csv")

# %%
#Exploración Inicial del dataset que ahora es un dataframe
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#Valida las primeras filas del archivo
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#Recibimos las estadísticas básicas de los campos numéricos en el df
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#Tamaño de la matriz número de filas y variables
df.shape
# Out:
# (1338, 7)

# %%
#cuenta el número de muestras nulas para cada una de las columnas
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#validar Nombre de columnas
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#validar tipos de datos de cada columna
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
